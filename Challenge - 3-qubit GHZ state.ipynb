# %%
from qiskit import *
from qiskit.tools.visualization import plot_histogram, plot_bloch_multivector, array_to_latex, plot_state_qsphere
from math import pi
# %matplotlib inline

# %%
#Quantum Circuit example for creating a four-bit Greenberger-Horne-Zeilenger state 
#circuit = QuantumCircuit(4)
#circuit.h(0)
#circuit.cx(0,1)
#circuit.cx(1,2)
#circuit.cx(2,3)
#circuit.draw(output="mpl")

# %%
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.cx(0,1)
circuit.cx(1,2)
circuit.draw(output="mpl")

# %%
simulator = Aer.get_backend("statevector_simulator")
result = execute(circuit, backend=simulator).result()
statevector = result.get_statevector()
array_to_latex(statevector)
# Out:
# $$
#
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & 0 & 0 & 0 & 0 & 0 & 0 & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
circuit.measure_all()

# %%
simulator = Aer.get_backend("qasm_simulator")
result = execute(circuit, backend=simulator).result()
count_result = result.get_counts()
plot_histogram(count_result)
